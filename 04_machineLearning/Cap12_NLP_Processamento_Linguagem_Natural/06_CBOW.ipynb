# %% [markdown]
# # <font color='blue'>Data Science Academy - Machine Learning</font>
#
# # <font color='blue'>Capítulo 12 - Processamento de Linguagem Natural</font>

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())

# %% [markdown]
# Obs: Este é um material de bônus incluído neste curso. PyTorch é estudado em detalhes no curso <a href="https://www.datascienceacademy.com.br/course?courseid=deep-learning-frameworks">Deep Learning Frameworks</a> e aplicado em PLN no curso <a href="https://www.datascienceacademy.com.br/course?courseid=processamento-de-linguagem-natural-e-reconhecimento-de-voz">Processamento de Linguagem Natural</a>.

# %% [markdown]
# ### Estudo de Caso - Inteligência Artificial Para Previsão de Sentenças em Embargos de Declaração

# %% [markdown]
# ![title](imagens/embargos.png)

# %% [markdown]
# **A definição deste estudo de caso está no manual em pdf no Capítulo 12 do Curso de <a href="https://www.datascienceacademy.com.br/course?courseid=machine-learning-engineer">Machine Learning</a>**.
#
# Faça a leitura do manual antes de prosseguir com o Estudo de Caso.

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install torch==1.5.0

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# Instala o PyTorch
# !pip install -q torch

# %%
# Imports
import torch
import torch.nn as nn
import numpy as np

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Alysson Melo" --iversions
# Out:
# Author: Alysson Melo
#
# numpy: 1.22.2
# torch: 2.5.0

# %% [markdown]
# ### Preparando os Dados
#
# O texto abaixo é um exemplo de embargo de declaração. Embora o texto represente um embargo, dados críticos foram substituídos por informações genéricas, o que não compromete o objetivo do estudo de caso.

# %%
# Texto de embargo de declaração
embargo = """O embargante sofreu o ajuizamento de ação de danos morais e materiais, cujo objeto é o reaver os 
valores pagos pelo sinal dado em um contrato de compra e venda de imóvel no qual não foi dado continuidade. Em 24 
de fevereiro de 2012, o Magistrado proferiu decisão de fls. 277 a 280, que condenou todas as demandadas 
solidariamente no seguinte teor: Diante de todo o exposto, com fundamento no art. 1234, I, do CPC/2015, 
julgo procedentes em parte os pedidos constantes na inicial, condenando solidariamente as demandadas, XPTO LTDA, 
BOB CAMARGO DE MORAES, a Pagarema título de indenização por danos morais, consoante fundamentação acima discorrida, 
o montante de R$ 1.500,00 (um mil e quinhentos reais), corrigidos monetariamente pelo INPC desde a data 
desta decisão, acrescidos de juros de 1% ao mês, a partir da citação; condeno ainda, à restituição do valor 
pago pelo demandante como sinal da entrada do imóvel, descontando apenas 20% (vinte por cento), referente às 
despesas, devendo incidir juros de 1% (um por cento) ao mês contados da citação e correção monetária pelo INPC a 
partir da sentença. Contudo, data venia, houve omissão e obscuridade na referida decisão, haja vista que a omissão 
se deu pela ausência dos julgamentos das preliminares (Necessidade de Perícia Técnica e a incompetência de 
Juizado Especial) proposta posteriormente em aditamento de contestação (Fls 251 a 254) para impugnar áudios 
juntados pelo embargado, autorizado a ser realizada pela Douta Magistrada em audiência de Conciliação, 
instrução e julgamento de fls 235 e 236, por ausência de intimação anterior para realizar a já tratada 
impugnação aos áudios anexados, Botafogo é o maior do Rio sim amores."""

# %%
# Limpeza do texto substituindo vírgulas e pontos por espaços e colocando as palavras em minúsculo
embargo = embargo.replace(',','').replace('.','').lower().split()

# %%
# Criação do corpus com o texto acima
corpus = set(embargo)

# %%
# Visualizamos o corpus
corpus
# Out:
# {'(fls',
#  '(necessidade',
#  '(um',
#  '(vinte',
#  '1%',
#  '1234',
#  '150000',
#  '20%',
#  '2012',
#  '235',
#  '236',
#  '24',
#  '251',
#  '254)',
#  '277',
#  '280',
#  'a',
#  'acima',
#  'acrescidos',
#  'aditamento',
#  'ainda',
#  'ajuizamento',
#  'amores',
#  'anexados',
#  'anterior',
#  'ao',
#  'aos',
#  'apenas',
#  'art',
#  'as',
#  'audiência',
#  'ausência',
#  'autorizado',
#  'ação',
#  'bob',
#  'botafogo',
#  'camargo',
#  'cento)',
#  'citação',
#  'citação;',
#  'com',
#  'como',
#  'compra',
#  'conciliação',
#  'condenando',
#  'condeno',
#  'condenou',
#  'consoante',
#  'constantes',
#  'contados',
#  'contestação',
#  'continuidade',
#  'contrato',
#  'contudo',
#  'correção',
#  'corrigidos',
#  'cpc/2015',
#  'cujo',
#  'da',
#  'dado',
#  'danos',
#  'das',
#  'data',
#  'de',
#  'decisão',
#  'demandadas',
#  'demandante',
#  'descontando',
#  'desde',
#  'despesas',
#  'desta',
#  'deu',
#  'devendo',
#  'diante',
#  'discorrida',
#  'do',
#  'dos',
#  'douta',
#  'e',
#  'em',
#  'embargado',
#  'embargante',
#  'entrada',
#  'especial)',
#  'exposto',
#  'fevereiro',
#  'fls',
#  'foi',
#  'fundamentação',
#  'fundamento',
#  'haja',
#  'houve',
#  'i',
#  'impugnar',
#  'impugnação',
#  'imóvel',
#  'incidir',
#  'incompetência',
#  'indenização',
#  'inicial',
#  'inpc',
#  'instrução',
#  'intimação',
#  'juizado',
#  'julgamento',
#  'julgamentos',
#  'julgo',
#  'juntados',
#  'juros',
#  'já',
#  'ltda',
#  'magistrada',
#  'magistrado',
#  'maior',
#  'materiais',
#  'mil',
#  'monetariamente',
#  'monetária',
#  'montante',
#  'moraes',
#  'morais',
#  'mês',
#  'na',
#  'no',
#  'não',
#  'o',
#  'objeto',
#  'obscuridade',
#  'omissão',
#  'os',
#  'pagarema',
#  'pago',
#  'pagos',
#  'para',
#  'parte',
#  'partir',
#  'pedidos',
#  'pela',
#  'pelo',
#  'perícia',
#  'por',
#  'posteriormente',
#  'preliminares',
#  'procedentes',
#  'proferiu',
#  'proposta',
#  'qual',
#  'que',
#  'quinhentos',
#  'r$',
#  'reais)',
#  'realizada',
#  'realizar',
#  'reaver',
#  'referente',
#  'referida',
#  'restituição',
#  'rio',
#  'se',
#  'seguinte',
#  'sentença',
#  'ser',
#  'sim',
#  'sinal',
#  'sofreu',
#  'solidariamente',
#  'teor:',
#  'todas',
#  'todo',
#  'tratada',
#  'técnica',
#  'título',
#  'um',
#  'valor',
#  'valores',
#  'venda',
#  'venia',
#  'vista',
#  'xpto',
#  'à',
#  'às',
#  'áudios',
#  'é'}

# %%
# Comprimento do corpus
corpus_length = len(corpus)

# %%
corpus_length
# Out:
# 183

# %%
# Dicionários para TF-IDF
dic_palavra = {}
dic_inverso_palavra = {}

# %%
# Loop pelo corpus para criar os dicionários
for i, palavra in enumerate(corpus):
    dic_palavra[palavra] = i
    dic_inverso_palavra[i] = palavra

# %%
dic_inverso_palavra
# Out:
# {0: 'cujo',
#  1: 'pago',
#  2: 'proferiu',
#  3: '(necessidade',
#  4: 'sentença',
#  5: 'não',
#  6: '251',
#  7: 'realizada',
#  8: 'entrada',
#  9: 'reaver',
#  10: 'condenou',
#  11: 'correção',
#  12: 'haja',
#  13: 'as',
#  14: 'diante',
#  15: 'objeto',
#  16: 'dado',
#  17: 'fls',
#  18: 'demandante',
#  19: 'para',
#  20: '1234',
#  21: 'cpc/2015',
#  22: 'fevereiro',
#  23: 'despesas',
#  24: 'todas',
#  25: 'reais)',
#  26: 'como',
#  27: 'e',
#  28: 'impugnar',
#  29: 'se',
#  30: 'acrescidos',
#  31: 'referente',
#  32: 'indenização',
#  33: 'parte',
#  34: 'mês',
#  35: '(vinte',
#  36: 'autorizado',
#  37: 'ltda',
#  38: 'morais',
#  39: '1%',
#  40: 'ação',
#  41: 'sinal',
#  42: 'deu',
#  43: 'procedentes',
#  44: 'qual',
#  45: 'imóvel',
#  46: '20%',
#  47: 'contados',
#  48: 'pagarema',
#  49: 'magistrada',
#  50: 'pela',
#  51: '280',
#  52: 'realizar',
#  53: 'proposta',
#  54: 'conciliação',
#  55: 'condeno',
#  56: 'incidir',
#  57: 'quinhentos',
#  58: 'incompetência',
#  59: 'corrigidos',
#  60: 'botafogo',
#  61: 'contudo',
#  62: 'cento)',
#  63: 'ausência',
#  64: 'venda',
#  65: 'ainda',
#  66: 'pagos',
#  67: 'em',
#  68: 'apenas',
#  69: 'especial)',
#  70: 'embargado',
#  71: 'maior',
#  72: 'citação;',
#  73: 'das',
#  74: 'juizado',
#  75: 'sim',
#  76: 'desde',
#  77: 'constantes',
#  78: 'valor',
#  79: 'houve',
#  80: 'data',
#  81: 'obscuridade',
#  82: 'ao',
#  83: 'pedidos',
#  84: 'moraes',
#  85: 'fundamentação',
#  86: 'contestação',
#  87: 'montante',
#  88: 'por',
#  89: 'embargante',
#  90: 'art',
#  91: '236',
#  92: 'demandadas',
#  93: 'amores',
#  94: 'às',
#  95: 'compra',
#  96: 'à',
#  97: 'julgamento',
#  98: 'os',
#  99: 'i',
#  100: 'venia',
#  101: 'danos',
#  102: 'técnica',
#  103: 'solidariamente',
#  104: 'do',
#  105: 'magistrado',
#  106: 'de',
#  107: 'valores',
#  108: '(fls',
#  109: 'vista',
#  110: 'decisão',
#  111: 'monetária',
#  112: 'desta',
#  113: 'devendo',
#  114: 'juros',
#  115: 'restituição',
#  116: 'na',
#  117: 'pelo',
#  118: 'acima',
#  119: '(um',
#  120: 'douta',
#  121: 'mil',
#  122: 'materiais',
#  123: 'aditamento',
#  124: 'monetariamente',
#  125: 'impugnação',
#  126: 'anexados',
#  127: 'um',
#  128: 'continuidade',
#  129: 'juntados',
#  130: 'contrato',
#  131: 'instrução',
#  132: 'descontando',
#  133: 'referida',
#  134: 'seguinte',
#  135: 'r$',
#  136: '24',
#  137: 'inpc',
#  138: 'anterior',
#  139: 'intimação',
#  140: 'consoante',
#  141: 'omissão',
#  142: 'discorrida',
#  143: '277',
#  144: 'exposto',
#  145: 'já',
#  146: 'aos',
#  147: 'todo',
#  148: 'dos',
#  149: 'com',
#  150: 'ajuizamento',
#  151: '235',
#  152: 'condenando',
#  153: 'áudios',
#  154: 'tratada',
#  155: 'audiência',
#  156: 'foi',
#  157: 'preliminares',
#  158: 'citação',
#  159: 'título',
#  160: 'posteriormente',
#  161: 'o',
#  162: 'fundamento',
#  163: '150000',
#  164: 'julgo',
#  165: 'ser',
#  166: 'sofreu',
#  167: 'camargo',
#  168: '254)',
#  169: 'bob',
#  170: 'no',
#  171: 'rio',
#  172: 'teor:',
#  173: 'inicial',
#  174: '2012',
#  175: 'a',
#  176: 'partir',
#  177: 'da',
#  178: 'que',
#  179: 'julgamentos',
#  180: 'perícia',
#  181: 'xpto',
#  182: 'é'}

# %%
dic_palavra
# Out:
# {'cujo': 0,
#  'pago': 1,
#  'proferiu': 2,
#  '(necessidade': 3,
#  'sentença': 4,
#  'não': 5,
#  '251': 6,
#  'realizada': 7,
#  'entrada': 8,
#  'reaver': 9,
#  'condenou': 10,
#  'correção': 11,
#  'haja': 12,
#  'as': 13,
#  'diante': 14,
#  'objeto': 15,
#  'dado': 16,
#  'fls': 17,
#  'demandante': 18,
#  'para': 19,
#  '1234': 20,
#  'cpc/2015': 21,
#  'fevereiro': 22,
#  'despesas': 23,
#  'todas': 24,
#  'reais)': 25,
#  'como': 26,
#  'e': 27,
#  'impugnar': 28,
#  'se': 29,
#  'acrescidos': 30,
#  'referente': 31,
#  'indenização': 32,
#  'parte': 33,
#  'mês': 34,
#  '(vinte': 35,
#  'autorizado': 36,
#  'ltda': 37,
#  'morais': 38,
#  '1%': 39,
#  'ação': 40,
#  'sinal': 41,
#  'deu': 42,
#  'procedentes': 43,
#  'qual': 44,
#  'imóvel': 45,
#  '20%': 46,
#  'contados': 47,
#  'pagarema': 48,
#  'magistrada': 49,
#  'pela': 50,
#  '280': 51,
#  'realizar': 52,
#  'proposta': 53,
#  'conciliação': 54,
#  'condeno': 55,
#  'incidir': 56,
#  'quinhentos': 57,
#  'incompetência': 58,
#  'corrigidos': 59,
#  'botafogo': 60,
#  'contudo': 61,
#  'cento)': 62,
#  'ausência': 63,
#  'venda': 64,
#  'ainda': 65,
#  'pagos': 66,
#  'em': 67,
#  'apenas': 68,
#  'especial)': 69,
#  'embargado': 70,
#  'maior': 71,
#  'citação;': 72,
#  'das': 73,
#  'juizado': 74,
#  'sim': 75,
#  'desde': 76,
#  'constantes': 77,
#  'valor': 78,
#  'houve': 79,
#  'data': 80,
#  'obscuridade': 81,
#  'ao': 82,
#  'pedidos': 83,
#  'moraes': 84,
#  'fundamentação': 85,
#  'contestação': 86,
#  'montante': 87,
#  'por': 88,
#  'embargante': 89,
#  'art': 90,
#  '236': 91,
#  'demandadas': 92,
#  'amores': 93,
#  'às': 94,
#  'compra': 95,
#  'à': 96,
#  'julgamento': 97,
#  'os': 98,
#  'i': 99,
#  'venia': 100,
#  'danos': 101,
#  'técnica': 102,
#  'solidariamente': 103,
#  'do': 104,
#  'magistrado': 105,
#  'de': 106,
#  'valores': 107,
#  '(fls': 108,
#  'vista': 109,
#  'decisão': 110,
#  'monetária': 111,
#  'desta': 112,
#  'devendo': 113,
#  'juros': 114,
#  'restituição': 115,
#  'na': 116,
#  'pelo': 117,
#  'acima': 118,
#  '(um': 119,
#  'douta': 120,
#  'mil': 121,
#  'materiais': 122,
#  'aditamento': 123,
#  'monetariamente': 124,
#  'impugnação': 125,
#  'anexados': 126,
#  'um': 127,
#  'continuidade': 128,
#  'juntados': 129,
#  'contrato': 130,
#  'instrução': 131,
#  'descontando': 132,
#  'referida': 133,
#  'seguinte': 134,
#  'r$': 135,
#  '24': 136,
#  'inpc': 137,
#  'anterior': 138,
#  'intimação': 139,
#  'consoante': 140,
#  'omissão': 141,
#  'discorrida': 142,
#  '277': 143,
#  'exposto': 144,
#  'já': 145,
#  'aos': 146,
#  'todo': 147,
#  'dos': 148,
#  'com': 149,
#  'ajuizamento': 150,
#  '235': 151,
#  'condenando': 152,
#  'áudios': 153,
#  'tratada': 154,
#  'audiência': 155,
#  'foi': 156,
#  'preliminares': 157,
#  'citação': 158,
#  'título': 159,
#  'posteriormente': 160,
#  'o': 161,
#  'fundamento': 162,
#  '150000': 163,
#  'julgo': 164,
#  'ser': 165,
#  'sofreu': 166,
#  'camargo': 167,
#  '254)': 168,
#  'bob': 169,
#  'no': 170,
#  'rio': 171,
#  'teor:': 172,
#  'inicial': 173,
#  '2012': 174,
#  'a': 175,
#  'partir': 176,
#  'da': 177,
#  'que': 178,
#  'julgamentos': 179,
#  'perícia': 180,
#  'xpto': 181,
#  'é': 182}

# %%
# Lista para receber os dados
dados = []

# %%
# Loop pelo texto par extrair sentenças e palavras
for i in range(2, len(embargo) - 2):
    sentence = [embargo[i-2], embargo[i-1], embargo[i+1], embargo[i+2]]
    target = embargo[i]
    dados.append((sentence, target))

# %%
[embargo[7-2], embargo[7-1], embargo[7+1], embargo[7+2]]
# Out:
# ['de', 'ação', 'danos', 'morais']

# %%
range(2, len(embargo) - 2)
# Out:
# range(2, 270)

# %% [markdown]
# Você leu o código acima e compreendeu o que foi feito? Observe esta linha:
#
# sentence = [embargo[i-2], embargo[i-1], embargo[i+1], embargo[i+2]]
#
# Para uma palavra no índice i, obtemos duas palavras antes e duas palavras depois. A palavra no índice i será o nosso target e a sentença será composta das duas palavras e duas palavras depois da palavra target.
#
# Após treinar o modelo, seremos capazes de prever cada palavra com base nas palavras a sua volta.
#
# Aqui um exemplo:

# %%
# Visualiza os dados
print(dados[3])
# Out:
# (['o', 'ajuizamento', 'ação', 'de'], 'de')

# %%
dados
# Out:
# [(['o', 'embargante', 'o', 'ajuizamento'], 'sofreu'),
#  (['embargante', 'sofreu', 'ajuizamento', 'de'], 'o'),
#  (['sofreu', 'o', 'de', 'ação'], 'ajuizamento'),
#  (['o', 'ajuizamento', 'ação', 'de'], 'de'),
#  (['ajuizamento', 'de', 'de', 'danos'], 'ação'),
#  (['de', 'ação', 'danos', 'morais'], 'de'),
#  (['ação', 'de', 'morais', 'e'], 'danos'),
#  (['de', 'danos', 'e', 'materiais'], 'morais'),
#  (['danos', 'morais', 'materiais', 'cujo'], 'e'),
#  (['morais', 'e', 'cujo', 'objeto'], 'materiais'),
#  (['e', 'materiais', 'objeto', 'é'], 'cujo'),
#  (['materiais', 'cujo', 'é', 'o'], 'objeto'),
#  (['cujo', 'objeto', 'o', 'reaver'], 'é'),
#  (['objeto', 'é', 'reaver', 'os'], 'o'),
#  (['é', 'o', 'os', 'valores'], 'reaver'),
#  (['o', 'reaver', 'valores', 'pagos'], 'os'),
#  (['reaver', 'os', 'pagos', 'pelo'], 'valores'),
#  (['os', 'valores', 'pelo', 'sinal'], 'pagos'),
#  (['valores', 'pagos', 'sinal', 'dado'], 'pelo'),
#  (['pagos', 'pelo', 'dado', 'em'], 'sinal'),
#  (['pelo', 'sinal', 'em', 'um'], 'dado'),
#  (['sinal', 'dado', 'um', 'contrato'], 'em'),
#  (['dado', 'em', 'contrato', 'de'], 'um'),
#  (['em', 'um', 'de', 'compra'], 'contrato'),
#  (['um', 'contrato', 'compra', 'e'], 'de'),
#  (['contrato', 'de', 'e', 'venda'], 'compra'),
#  (['de', 'compra', 'venda', 'de'], 'e'),
#  (['compra', 'e', 'de', 'imóvel'], 'venda'),
#  (['e', 'venda', 'imóvel', 'no'], 'de'),
#  (['venda', 'de', 'no', 'qual'], 'imóvel'),
#  (['de', 'imóvel', 'qual', 'não'], 'no'),
#  (['imóvel', 'no', 'não', 'foi'], 'qual'),
#  (['no', 'qual', 'foi', 'dado'], 'não'),
#  (['qual', 'não', 'dado', 'continuidade'], 'foi'),
#  (['não', 'foi', 'continuidade', 'em'], 'dado'),
#  (['foi', 'dado', 'em', '24'], 'continuidade'),
#  (['dado', 'continuidade', '24', 'de'], 'em'),
#  (['continuidade', 'em', 'de', 'fevereiro'], '24'),
#  (['em', '24', 'fevereiro', 'de'], 'de'),
#  (['24', 'de', 'de', '2012'], 'fevereiro'),
#  (['de', 'fevereiro', '2012', 'o'], 'de'),
#  (['fevereiro', 'de', 'o', 'magistrado'], '2012'),
#  (['de', '2012', 'magistrado', 'proferiu'], 'o'),
#  (['2012', 'o', 'proferiu', 'decisão'], 'magistrado'),
#  (['o', 'magistrado', 'decisão', 'de'], 'proferiu'),
#  (['magistrado', 'proferiu', 'de', 'fls'], 'decisão'),
#  (['proferiu', 'decisão', 'fls', '277'], 'de'),
#  (['decisão', 'de', '277', 'a'], 'fls'),
#  (['de', 'fls', 'a', '280'], '277'),
#  (['fls', '277', '280', 'que'], 'a'),
#  (['277', 'a', 'que', 'condenou'], '280'),
#  (['a', '280', 'condenou', 'todas'], 'que'),
#  (['280', 'que', 'todas', 'as'], 'condenou'),
#  (['que', 'condenou', 'as', 'demandadas'], 'todas'),
#  (['condenou', 'todas', 'demandadas', 'solidariamente'], 'as'),
#  (['todas', 'as', 'solidariamente', 'no'], 'demandadas'),
#  (['as', 'demandadas', 'no', 'seguinte'], 'solidariamente'),
#  (['demandadas', 'solidariamente', 'seguinte', 'teor:'], 'no'),
#  (['solidariamente', 'no', 'teor:', 'diante'], 'seguinte'),
#  (['no', 'seguinte', 'diante', 'de'], 'teor:'),
#  (['seguinte', 'teor:', 'de', 'todo'], 'diante'),
#  (['teor:', 'diante', 'todo', 'o'], 'de'),
#  (['diante', 'de', 'o', 'exposto'], 'todo'),
#  (['de', 'todo', 'exposto', 'com'], 'o'),
#  (['todo', 'o', 'com', 'fundamento'], 'exposto'),
#  (['o', 'exposto', 'fundamento', 'no'], 'com'),
#  (['exposto', 'com', 'no', 'art'], 'fundamento'),
#  (['com', 'fundamento', 'art', '1234'], 'no'),
#  (['fundamento', 'no', '1234', 'i'], 'art'),
#  (['no', 'art', 'i', 'do'], '1234'),
#  (['art', '1234', 'do', 'cpc/2015'], 'i'),
#  (['1234', 'i', 'cpc/2015', 'julgo'], 'do'),
#  (['i', 'do', 'julgo', 'procedentes'], 'cpc/2015'),
#  (['do', 'cpc/2015', 'procedentes', 'em'], 'julgo'),
#  (['cpc/2015', 'julgo', 'em', 'parte'], 'procedentes'),
#  (['julgo', 'procedentes', 'parte', 'os'], 'em'),
#  (['procedentes', 'em', 'os', 'pedidos'], 'parte'),
#  (['em', 'parte', 'pedidos', 'constantes'], 'os'),
#  (['parte', 'os', 'constantes', 'na'], 'pedidos'),
#  (['os', 'pedidos', 'na', 'inicial'], 'constantes'),
#  (['pedidos', 'constantes', 'inicial', 'condenando'], 'na'),
#  (['constantes', 'na', 'condenando', 'solidariamente'], 'inicial'),
#  (['na', 'inicial', 'solidariamente', 'as'], 'condenando'),
#  (['inicial', 'condenando', 'as', 'demandadas'], 'solidariamente'),
#  (['condenando', 'solidariamente', 'demandadas', 'xpto'], 'as'),
#  (['solidariamente', 'as', 'xpto', 'ltda'], 'demandadas'),
#  (['as', 'demandadas', 'ltda', 'bob'], 'xpto'),
#  (['demandadas', 'xpto', 'bob', 'camargo'], 'ltda'),
#  (['xpto', 'ltda', 'camargo', 'de'], 'bob'),
#  (['ltda', 'bob', 'de', 'moraes'], 'camargo'),
#  (['bob', 'camargo', 'moraes', 'a'], 'de'),
#  (['camargo', 'de', 'a', 'pagarema'], 'moraes'),
#  (['de', 'moraes', 'pagarema', 'título'], 'a'),
#  (['moraes', 'a', 'título', 'de'], 'pagarema'),
#  (['a', 'pagarema', 'de', 'indenização'], 'título'),
#  (['pagarema', 'título', 'indenização', 'por'], 'de'),
#  (['título', 'de', 'por', 'danos'], 'indenização'),
#  (['de', 'indenização', 'danos', 'morais'], 'por'),
#  (['indenização', 'por', 'morais', 'consoante'], 'danos'),
#  (['por', 'danos', 'consoante', 'fundamentação'], 'morais'),
#  (['danos', 'morais', 'fundamentação', 'acima'], 'consoante'),
#  (['morais', 'consoante', 'acima', 'discorrida'], 'fundamentação'),
#  (['consoante', 'fundamentação', 'discorrida', 'o'], 'acima'),
#  (['fundamentação', 'acima', 'o', 'montante'], 'discorrida'),
#  (['acima', 'discorrida', 'montante', 'de'], 'o'),
#  (['discorrida', 'o', 'de', 'r$'], 'montante'),
#  (['o', 'montante', 'r$', '150000'], 'de'),
#  (['montante', 'de', '150000', '(um'], 'r$'),
#  (['de', 'r$', '(um', 'mil'], '150000'),
#  (['r$', '150000', 'mil', 'e'], '(um'),
#  (['150000', '(um', 'e', 'quinhentos'], 'mil'),
#  (['(um', 'mil', 'quinhentos', 'reais)'], 'e'),
#  (['mil', 'e', 'reais)', 'corrigidos'], 'quinhentos'),
#  (['e', 'quinhentos', 'corrigidos', 'monetariamente'], 'reais)'),
#  (['quinhentos', 'reais)', 'monetariamente', 'pelo'], 'corrigidos'),
#  (['reais)', 'corrigidos', 'pelo', 'inpc'], 'monetariamente'),
#  (['corrigidos', 'monetariamente', 'inpc', 'desde'], 'pelo'),
#  (['monetariamente', 'pelo', 'desde', 'a'], 'inpc'),
#  (['pelo', 'inpc', 'a', 'data'], 'desde'),
#  (['inpc', 'desde', 'data', 'desta'], 'a'),
#  (['desde', 'a', 'desta', 'decisão'], 'data'),
#  (['a', 'data', 'decisão', 'acrescidos'], 'desta'),
#  (['data', 'desta', 'acrescidos', 'de'], 'decisão'),
#  (['desta', 'decisão', 'de', 'juros'], 'acrescidos'),
#  (['decisão', 'acrescidos', 'juros', 'de'], 'de'),
#  (['acrescidos', 'de', 'de', '1%'], 'juros'),
#  (['de', 'juros', '1%', 'ao'], 'de'),
#  (['juros', 'de', 'ao', 'mês'], '1%'),
#  (['de', '1%', 'mês', 'a'], 'ao'),
#  (['1%', 'ao', 'a', 'partir'], 'mês'),
#  (['ao', 'mês', 'partir', 'da'], 'a'),
#  (['mês', 'a', 'da', 'citação;'], 'partir'),
#  (['a', 'partir', 'citação;', 'condeno'], 'da'),
#  (['partir', 'da', 'condeno', 'ainda'], 'citação;'),
#  (['da', 'citação;', 'ainda', 'à'], 'condeno'),
#  (['citação;', 'condeno', 'à', 'restituição'], 'ainda'),
#  (['condeno', 'ainda', 'restituição', 'do'], 'à'),
#  (['ainda', 'à', 'do', 'valor'], 'restituição'),
#  (['à', 'restituição', 'valor', 'pago'], 'do'),
#  (['restituição', 'do', 'pago', 'pelo'], 'valor'),
#  (['do', 'valor', 'pelo', 'demandante'], 'pago'),
#  (['valor', 'pago', 'demandante', 'como'], 'pelo'),
#  (['pago', 'pelo', 'como', 'sinal'], 'demandante'),
#  (['pelo', 'demandante', 'sinal', 'da'], 'como'),
#  (['demandante', 'como', 'da', 'entrada'], 'sinal'),
#  (['como', 'sinal', 'entrada', 'do'], 'da'),
#  (['sinal', 'da', 'do', 'imóvel'], 'entrada'),
#  (['da', 'entrada', 'imóvel', 'descontando'], 'do'),
#  (['entrada', 'do', 'descontando', 'apenas'], 'imóvel'),
#  (['do', 'imóvel', 'apenas', '20%'], 'descontando'),
#  (['imóvel', 'descontando', '20%', '(vinte'], 'apenas'),
#  (['descontando', 'apenas', '(vinte', 'por'], '20%'),
#  (['apenas', '20%', 'por', 'cento)'], '(vinte'),
#  (['20%', '(vinte', 'cento)', 'referente'], 'por'),
#  (['(vinte', 'por', 'referente', 'às'], 'cento)'),
#  (['por', 'cento)', 'às', 'despesas'], 'referente'),
#  (['cento)', 'referente', 'despesas', 'devendo'], 'às'),
#  (['referente', 'às', 'devendo', 'incidir'], 'despesas'),
#  (['às', 'despesas', 'incidir', 'juros'], 'devendo'),
#  (['despesas', 'devendo', 'juros', 'de'], 'incidir'),
#  (['devendo', 'incidir', 'de', '1%'], 'juros'),
#  (['incidir', 'juros', '1%', '(um'], 'de'),
#  (['juros', 'de', '(um', 'por'], '1%'),
#  (['de', '1%', 'por', 'cento)'], '(um'),
#  (['1%', '(um', 'cento)', 'ao'], 'por'),
#  (['(um', 'por', 'ao', 'mês'], 'cento)'),
#  (['por', 'cento)', 'mês', 'contados'], 'ao'),
#  (['cento)', 'ao', 'contados', 'da'], 'mês'),
#  (['ao', 'mês', 'da', 'citação'], 'contados'),
#  (['mês', 'contados', 'citação', 'e'], 'da'),
#  (['contados', 'da', 'e', 'correção'], 'citação'),
#  (['da', 'citação', 'correção', 'monetária'], 'e'),
#  (['citação', 'e', 'monetária', 'pelo'], 'correção'),
#  (['e', 'correção', 'pelo', 'inpc'], 'monetária'),
#  (['correção', 'monetária', 'inpc', 'a'], 'pelo'),
#  (['monetária', 'pelo', 'a', 'partir'], 'inpc'),
#  (['pelo', 'inpc', 'partir', 'da'], 'a'),
#  (['inpc', 'a', 'da', 'sentença'], 'partir'),
#  (['a', 'partir', 'sentença', 'contudo'], 'da'),
#  (['partir', 'da', 'contudo', 'data'], 'sentença'),
#  (['da', 'sentença', 'data', 'venia'], 'contudo'),
#  (['sentença', 'contudo', 'venia', 'houve'], 'data'),
#  (['contudo', 'data', 'houve', 'omissão'], 'venia'),
#  (['data', 'venia', 'omissão', 'e'], 'houve'),
#  (['venia', 'houve', 'e', 'obscuridade'], 'omissão'),
#  (['houve', 'omissão', 'obscuridade', 'na'], 'e'),
#  (['omissão', 'e', 'na', 'referida'], 'obscuridade'),
#  (['e', 'obscuridade', 'referida', 'decisão'], 'na'),
#  (['obscuridade', 'na', 'decisão', 'haja'], 'referida'),
#  (['na', 'referida', 'haja', 'vista'], 'decisão'),
#  (['referida', 'decisão', 'vista', 'que'], 'haja'),
#  (['decisão', 'haja', 'que', 'a'], 'vista'),
#  (['haja', 'vista', 'a', 'omissão'], 'que'),
#  (['vista', 'que', 'omissão', 'se'], 'a'),
#  (['que', 'a', 'se', 'deu'], 'omissão'),
#  (['a', 'omissão', 'deu', 'pela'], 'se'),
#  (['omissão', 'se', 'pela', 'ausência'], 'deu'),
#  (['se', 'deu', 'ausência', 'dos'], 'pela'),
#  (['deu', 'pela', 'dos', 'julgamentos'], 'ausência'),
#  (['pela', 'ausência', 'julgamentos', 'das'], 'dos'),
#  (['ausência', 'dos', 'das', 'preliminares'], 'julgamentos'),
#  (['dos', 'julgamentos', 'preliminares', '(necessidade'], 'das'),
#  (['julgamentos', 'das', '(necessidade', 'de'], 'preliminares'),
#  (['das', 'preliminares', 'de', 'perícia'], '(necessidade'),
#  (['preliminares', '(necessidade', 'perícia', 'técnica'], 'de'),
#  (['(necessidade', 'de', 'técnica', 'e'], 'perícia'),
#  (['de', 'perícia', 'e', 'a'], 'técnica'),
#  (['perícia', 'técnica', 'a', 'incompetência'], 'e'),
#  (['técnica', 'e', 'incompetência', 'de'], 'a'),
#  (['e', 'a', 'de', 'juizado'], 'incompetência'),
#  (['a', 'incompetência', 'juizado', 'especial)'], 'de'),
#  (['incompetência', 'de', 'especial)', 'proposta'], 'juizado'),
#  (['de', 'juizado', 'proposta', 'posteriormente'], 'especial)'),
#  (['juizado', 'especial)', 'posteriormente', 'em'], 'proposta'),
#  (['especial)', 'proposta', 'em', 'aditamento'], 'posteriormente'),
#  (['proposta', 'posteriormente', 'aditamento', 'de'], 'em'),
#  (['posteriormente', 'em', 'de', 'contestação'], 'aditamento'),
#  (['em', 'aditamento', 'contestação', '(fls'], 'de'),
#  (['aditamento', 'de', '(fls', '251'], 'contestação'),
#  (['de', 'contestação', '251', 'a'], '(fls'),
#  (['contestação', '(fls', 'a', '254)'], '251'),
#  (['(fls', '251', '254)', 'para'], 'a'),
#  (['251', 'a', 'para', 'impugnar'], '254)'),
#  (['a', '254)', 'impugnar', 'áudios'], 'para'),
#  (['254)', 'para', 'áudios', 'juntados'], 'impugnar'),
#  (['para', 'impugnar', 'juntados', 'pelo'], 'áudios'),
#  (['impugnar', 'áudios', 'pelo', 'embargado'], 'juntados'),
#  (['áudios', 'juntados', 'embargado', 'autorizado'], 'pelo'),
#  (['juntados', 'pelo', 'autorizado', 'a'], 'embargado'),
#  (['pelo', 'embargado', 'a', 'ser'], 'autorizado'),
#  (['embargado', 'autorizado', 'ser', 'realizada'], 'a'),
#  (['autorizado', 'a', 'realizada', 'pela'], 'ser'),
#  (['a', 'ser', 'pela', 'douta'], 'realizada'),
#  (['ser', 'realizada', 'douta', 'magistrada'], 'pela'),
#  (['realizada', 'pela', 'magistrada', 'em'], 'douta'),
#  (['pela', 'douta', 'em', 'audiência'], 'magistrada'),
#  (['douta', 'magistrada', 'audiência', 'de'], 'em'),
#  (['magistrada', 'em', 'de', 'conciliação'], 'audiência'),
#  (['em', 'audiência', 'conciliação', 'instrução'], 'de'),
#  (['audiência', 'de', 'instrução', 'e'], 'conciliação'),
#  (['de', 'conciliação', 'e', 'julgamento'], 'instrução'),
#  (['conciliação', 'instrução', 'julgamento', 'de'], 'e'),
#  (['instrução', 'e', 'de', 'fls'], 'julgamento'),
#  (['e', 'julgamento', 'fls', '235'], 'de'),
#  (['julgamento', 'de', '235', 'e'], 'fls'),
#  (['de', 'fls', 'e', '236'], '235'),
#  (['fls', '235', '236', 'por'], 'e'),
#  (['235', 'e', 'por', 'ausência'], '236'),
#  (['e', '236', 'ausência', 'de'], 'por'),
#  (['236', 'por', 'de', 'intimação'], 'ausência'),
#  (['por', 'ausência', 'intimação', 'anterior'], 'de'),
#  (['ausência', 'de', 'anterior', 'para'], 'intimação'),
#  (['de', 'intimação', 'para', 'realizar'], 'anterior'),
#  (['intimação', 'anterior', 'realizar', 'a'], 'para'),
#  (['anterior', 'para', 'a', 'já'], 'realizar'),
#  (['para', 'realizar', 'já', 'tratada'], 'a'),
#  (['realizar', 'a', 'tratada', 'impugnação'], 'já'),
#  (['a', 'já', 'impugnação', 'aos'], 'tratada'),
#  (['já', 'tratada', 'aos', 'áudios'], 'impugnação'),
#  (['tratada', 'impugnação', 'áudios', 'anexados'], 'aos'),
#  (['impugnação', 'aos', 'anexados', 'botafogo'], 'áudios'),
#  (['aos', 'áudios', 'botafogo', 'é'], 'anexados'),
#  (['áudios', 'anexados', 'é', 'o'], 'botafogo'),
#  (['anexados', 'botafogo', 'o', 'maior'], 'é'),
#  (['botafogo', 'é', 'maior', 'do'], 'o'),
#  (['é', 'o', 'do', 'rio'], 'maior'),
#  (['o', 'maior', 'rio', 'sim'], 'do'),
#  (['maior', 'do', 'sim', 'amores'], 'rio')]

# %% [markdown]
# As quatro palavras na lista serão os dados de entrada e a palavra fora da lista ('de' nesse caso), será a variável de saída.

# %% [markdown]
# ### Construção do Modelo CBoW

# %%
# Vamos definir o comprimento de cada embedding
embedding_length = 20

# %%
# Classe para o modelo
class CBoW(torch.nn.Module):

    # Método construtor
    def __init__(self, corpus_length, embedding_dim):
        super(CBoW, self).__init__()
        
        # Camada de entrada do modelo para criação da embedding
        self.embeddings = nn.Embedding(corpus_length, embedding_dim)

        # Camadas lineares
        self.linear1 = nn.Linear(embedding_dim, 64)
        self.linear2 = nn.Linear(64, corpus_length)
        
        # Camadas de ativação
        self.activation_function1 = nn.ReLU()
        self.activation_function2 = nn.LogSoftmax(dim = -1)

    # Passo (forward)
    def forward(self, inputs):
        
        # Aqui definimos a ordem ds camadas da rede neural
        embeds = sum(self.embeddings(inputs)).view(1,-1)
        out = self.linear1(embeds)
        out = self.activation_function1(out)
        out = self.linear2(out)
        out = self.activation_function2(out)
        return out

    # Obtém a word_emdedding
    def get_word_emdedding(self, word):
        word = torch.LongTensor([dic_palavra[word]])
        return self.embeddings(word).view(1,-1)

# %%
# Cria o modelo CBoW
modelo = CBoW(corpus_length, embedding_length)

# %%
# Função de custo
loss_function = nn.NLLLoss()

# %%
# Otimizador do modelo (backpropagation)
optimizer = torch.optim.SGD(modelo.parameters(), lr = 0.01)

# %%
# Função para criar o vetor de sentenças, necessário para treinar o modelo
def make_sentence_vector(sentence, word_dict):
    idxs = [word_dict[w] for w in sentence]
    return torch.tensor(idxs, dtype = torch.long)

# %%
# Aqui está nosso dicionário de palavras
dic_palavra
# Out:
# {'20%': 0,
#  'para': 1,
#  'realizar': 2,
#  'acrescidos': 3,
#  'incompetência': 4,
#  'julgamentos': 5,
#  'juizado': 6,
#  'perícia': 7,
#  '251': 8,
#  'montante': 9,
#  'obscuridade': 10,
#  'omissão': 11,
#  'venda': 12,
#  '236': 13,
#  'corrigidos': 14,
#  'na': 15,
#  'embargado': 16,
#  'pagarema': 17,
#  'posteriormente': 18,
#  'sinal': 19,
#  'um': 20,
#  'aos': 21,
#  'preliminares': 22,
#  '(um': 23,
#  'pago': 24,
#  'dos': 25,
#  'houve': 26,
#  '1%': 27,
#  'quinhentos': 28,
#  'demandadas': 29,
#  'mês': 30,
#  'condenou': 31,
#  'discorrida': 32,
#  'pela': 33,
#  'como': 34,
#  'valores': 35,
#  'no': 36,
#  '2012': 37,
#  'partir': 38,
#  '280': 39,
#  'impugnação': 40,
#  'inpc': 41,
#  'correção': 42,
#  'áudios': 43,
#  'desde': 44,
#  'restituição': 45,
#  'às': 46,
#  'ajuizamento': 47,
#  'reais)': 48,
#  'solidariamente': 49,
#  'data': 50,
#  'tratada': 51,
#  'haja': 52,
#  'apenas': 53,
#  'impugnar': 54,
#  'diante': 55,
#  '(vinte': 56,
#  'julgamento': 57,
#  'compra': 58,
#  'seguinte': 59,
#  'cento)': 60,
#  'demandante': 61,
#  'descontando': 62,
#  'contados': 63,
#  'se': 64,
#  '254)': 65,
#  '(fls': 66,
#  'autorizado': 67,
#  'contudo': 68,
#  'técnica': 69,
#  'referida': 70,
#  'sofreu': 71,
#  'art': 72,
#  'que': 73,
#  'em': 74,
#  'a': 75,
#  'decisão': 76,
#  'citação;': 77,
#  'objeto': 78,
#  '277': 79,
#  'anexados': 80,
#  'já': 81,
#  'à': 82,
#  'proferiu': 83,
#  'inicial': 84,
#  'fundamento': 85,
#  'valor': 86,
#  'pagos': 87,
#  '24': 88,
#  'contrato': 89,
#  'camargo': 90,
#  'título': 91,
#  'ltda': 92,
#  'cujo': 93,
#  'de': 94,
#  'não': 95,
#  'monetariamente': 96,
#  'dado': 97,
#  'foi': 98,
#  'exposto': 99,
#  'douta': 100,
#  'os': 101,
#  'ausência': 102,
#  'magistrada': 103,
#  'audiência': 104,
#  'entrada': 105,
#  'devendo': 106,
#  'venia': 107,
#  'intimação': 108,
#  'sentença': 109,
#  'pedidos': 110,
#  'com': 111,
#  '1234': 112,
#  '150000': 113,
#  'danos': 114,
#  'o': 115,
#  'r$': 116,
#  '235': 117,
#  'teor:': 118,
#  'parte': 119,
#  'constantes': 120,
#  'qual': 121,
#  'é': 122,
#  'ainda': 123,
#  'da': 124,
#  'todas': 125,
#  'reaver': 126,
#  'pelo': 127,
#  'condenando': 128,
#  'consoante': 129,
#  'as': 130,
#  'i': 131,
#  'moraes': 132,
#  'desta': 133,
#  'especial)': 134,
#  'ser': 135,
#  'das': 136,
#  'todo': 137,
#  'embargante': 138,
#  'do': 139,
#  '(necessidade': 140,
#  'incidir': 141,
#  'juros': 142,
#  'juntados': 143,
#  'despesas': 144,
#  'referente': 145,
#  'fevereiro': 146,
#  'morais': 147,
#  'fls': 148,
#  'magistrado': 149,
#  'contestação': 150,
#  'conciliação': 151,
#  'vista': 152,
#  'bob': 153,
#  'julgo': 154,
#  'proposta': 155,
#  'ação': 156,
#  'cpc/2015': 157,
#  'xpto': 158,
#  'citação': 159,
#  'anterior': 160,
#  'por': 161,
#  'materiais': 162,
#  'monetária': 163,
#  'procedentes': 164,
#  'aditamento': 165,
#  'continuidade': 166,
#  'e': 167,
#  'fundamentação': 168,
#  'mil': 169,
#  'realizada': 170,
#  'indenização': 171,
#  'deu': 172,
#  'instrução': 173,
#  'imóvel': 174,
#  'acima': 175,
#  'ao': 176,
#  'condeno': 177}

# %%
# O dicionário de palavras será convertido em um vetor de sentenças. Aqui um exemplo:
print(make_sentence_vector(['pela','ausência','dos','julgamentos'], dic_palavra))
# Out:
# tensor([ 50,  63, 148, 179])

# %% [markdown]
# ### Treinamento do Modelo

# %%
# Loop por 150 passadas (epochs) de treinamento
for epoch in range(150):
    
    # Inicia o erro da época com 0
    epoch_loss = 0
    
    # Loop pelos dados de entrada (sentence) e saída (target)
    for sentence, target in dados:
        
        # Inicializa os gradientes com zero
        modelo.zero_grad()
        
        # Cria o vetor de sentença com os dados de entrada (que devem estar no dicionário de palavras)
        sentence_vector = make_sentence_vector(sentence, dic_palavra)  
        
        # Usa o vetor para fazer previsões com o modelo e retorna as probabilidades
        log_probs = modelo(sentence_vector)
        
        # Calcula o erro do modelo
        loss = loss_function(log_probs, torch.tensor([dic_palavra[target]], dtype = torch.long))
        
        # Chama o método de backpropagation para calcular o gradiente da derivada
        loss.backward()
        
        # Otimiza os pesos do modelo e segue para a próxima passada
        # É aqui que o aprendizado acontece
        optimizer.step()
        
        # Atualiza o erro da época
        epoch_loss += loss.data
        
    # Imprime epoch e erro da epoch    
    print('Epoch: ' + str(epoch) + ', Erro do Modelo: ' + str(epoch_loss.item()))
# Out:
# Epoch: 0, Erro do Modelo: 1415.9918212890625
# Epoch: 1, Erro do Modelo: 1284.362060546875
# Epoch: 2, Erro do Modelo: 1188.13232421875
# Epoch: 3, Erro do Modelo: 1093.7626953125
# Epoch: 4, Erro do Modelo: 993.5388793945312
# Epoch: 5, Erro do Modelo: 885.3431396484375
# Epoch: 6, Erro do Modelo: 769.9146118164062
# Epoch: 7, Erro do Modelo: 651.0857543945312
# Epoch: 8, Erro do Modelo: 534.0026245117188
# Epoch: 9, Erro do Modelo: 424.0988464355469
# Epoch: 10, Erro do Modelo: 326.40118408203125
# Epoch: 11, Erro do Modelo: 244.1823272705078
# Epoch: 12, Erro do Modelo: 179.64553833007812
# Epoch: 13, Erro do Modelo: 131.3838348388672
# Epoch: 14, Erro do Modelo: 97.54369354248047
# Epoch: 15, Erro do Modelo: 74.14595031738281
# Epoch: 16, Erro do Modelo: 57.648895263671875
# Epoch: 17, Erro do Modelo: 46.07587814331055
# Epoch: 18, Erro do Modelo: 37.84537887573242
# Epoch: 19, Erro do Modelo: 31.806264877319336
# Epoch: 20, Erro do Modelo: 27.29094123840332
# Epoch: 21, Erro do Modelo: 23.805389404296875
# Epoch: 22, Erro do Modelo: 21.08869743347168
# Epoch: 23, Erro do Modelo: 18.904722213745117
# Epoch: 24, Erro do Modelo: 17.118833541870117
# Epoch: 25, Erro do Modelo: 15.614067077636719
# Epoch: 26, Erro do Modelo: 14.362833976745605
# Epoch: 27, Erro do Modelo: 13.279577255249023
# Epoch: 28, Erro do Modelo: 12.34125804901123
# Epoch: 29, Erro do Modelo: 11.524622917175293
# Epoch: 30, Erro do Modelo: 10.80256462097168
# Epoch: 31, Erro do Modelo: 10.163518905639648
# Epoch: 32, Erro do Modelo: 9.590428352355957
# Epoch: 33, Erro do Modelo: 9.076655387878418
# Epoch: 34, Erro do Modelo: 8.611011505126953
# Epoch: 35, Erro do Modelo: 8.192368507385254
# Epoch: 36, Erro do Modelo: 7.808606147766113
# Epoch: 37, Erro do Modelo: 7.4570488929748535
# Epoch: 38, Erro do Modelo: 7.1352152824401855
# Epoch: 39, Erro do Modelo: 6.837887763977051
# Epoch: 40, Erro do Modelo: 6.563346862792969
# Epoch: 41, Erro do Modelo: 6.30832052230835
# Epoch: 42, Erro do Modelo: 6.072536468505859
# Epoch: 43, Erro do Modelo: 5.851900100708008
# Epoch: 44, Erro do Modelo: 5.64517068862915
# Epoch: 45, Erro do Modelo: 5.454691410064697
# Epoch: 46, Erro do Modelo: 5.273731708526611
# Epoch: 47, Erro do Modelo: 5.1042351722717285
# Epoch: 48, Erro do Modelo: 4.944529056549072
# Epoch: 49, Erro do Modelo: 4.794281005859375
# Epoch: 50, Erro do Modelo: 4.652463912963867
# Epoch: 51, Erro do Modelo: 4.518005847930908
# Epoch: 52, Erro do Modelo: 4.390944480895996
# Epoch: 53, Erro do Modelo: 4.270266056060791
# Epoch: 54, Erro do Modelo: 4.156232833862305
# Epoch: 55, Erro do Modelo: 4.046844005584717
# Epoch: 56, Erro do Modelo: 3.9438741207122803
# Epoch: 57, Erro do Modelo: 3.8452675342559814
# Epoch: 58, Erro do Modelo: 3.7511277198791504
# Epoch: 59, Erro do Modelo: 3.6614952087402344
# Epoch: 60, Erro do Modelo: 3.5755670070648193
# Epoch: 61, Erro do Modelo: 3.493279218673706
# Epoch: 62, Erro do Modelo: 3.414872884750366
# Epoch: 63, Erro do Modelo: 3.339294910430908
# Epoch: 64, Erro do Modelo: 3.267472982406616
# Epoch: 65, Erro do Modelo: 3.1979949474334717
# Epoch: 66, Erro do Modelo: 3.13130784034729
# Epoch: 67, Erro do Modelo: 3.0672125816345215
# Epoch: 68, Erro do Modelo: 3.0054938793182373
# Epoch: 69, Erro do Modelo: 2.946228504180908
# Epoch: 70, Erro do Modelo: 2.888791799545288
# Epoch: 71, Erro do Modelo: 2.8339035511016846
# Epoch: 72, Erro do Modelo: 2.78070068359375
# Epoch: 73, Erro do Modelo: 2.7293214797973633
# Epoch: 74, Erro do Modelo: 2.679729700088501
# Epoch: 75, Erro do Modelo: 2.631831407546997
# Epoch: 76, Erro do Modelo: 2.5855679512023926
# Epoch: 77, Erro do Modelo: 2.5405731201171875
# Epoch: 78, Erro do Modelo: 2.4974849224090576
# Epoch: 79, Erro do Modelo: 2.4553887844085693
# Epoch: 80, Erro do Modelo: 2.4147980213165283
# Epoch: 81, Erro do Modelo: 2.375368118286133
# Epoch: 82, Erro do Modelo: 2.3373050689697266
# Epoch: 83, Erro do Modelo: 2.2999064922332764
# Epoch: 84, Erro do Modelo: 2.264192819595337
# Epoch: 85, Erro do Modelo: 2.229235887527466
# Epoch: 86, Erro do Modelo: 2.1952528953552246
# Epoch: 87, Erro do Modelo: 2.1622965335845947
# Epoch: 88, Erro do Modelo: 2.1302590370178223
# Epoch: 89, Erro do Modelo: 2.099050760269165
# Epoch: 90, Erro do Modelo: 2.068711519241333
# Epoch: 91, Erro do Modelo: 2.0391175746917725
# Epoch: 92, Erro do Modelo: 2.010525703430176
# Epoch: 93, Erro do Modelo: 1.9824984073638916
# Epoch: 94, Erro do Modelo: 1.9553136825561523
# Epoch: 95, Erro do Modelo: 1.92872154712677
# Epoch: 96, Erro do Modelo: 1.9028546810150146
# Epoch: 97, Erro do Modelo: 1.8774656057357788
# Epoch: 98, Erro do Modelo: 1.85305917263031
# Epoch: 99, Erro do Modelo: 1.8289952278137207
# Epoch: 100, Erro do Modelo: 1.8056070804595947
# Epoch: 101, Erro do Modelo: 1.7826794385910034
# Epoch: 102, Erro do Modelo: 1.760311245918274
# Epoch: 103, Erro do Modelo: 1.7385170459747314
# Epoch: 104, Erro do Modelo: 1.7170993089675903
# Epoch: 105, Erro do Modelo: 1.6963921785354614
# Epoch: 106, Erro do Modelo: 1.6760131120681763
# Epoch: 107, Erro do Modelo: 1.6561301946640015
# Epoch: 108, Erro do Modelo: 1.6366403102874756
# Epoch: 109, Erro do Modelo: 1.61763334274292
# Epoch: 110, Erro do Modelo: 1.5989629030227661
# Epoch: 111, Erro do Modelo: 1.5807114839553833
# Epoch: 112, Erro do Modelo: 1.5629593133926392
# Epoch: 113, Erro do Modelo: 1.5454812049865723
# Epoch: 114, Erro do Modelo: 1.5283664464950562
# Epoch: 115, Erro do Modelo: 1.511600136756897
# Epoch: 116, Erro do Modelo: 1.495175838470459
# Epoch: 117, Erro do Modelo: 1.4791580438613892
# Epoch: 118, Erro do Modelo: 1.4633487462997437
# Epoch: 119, Erro do Modelo: 1.4479410648345947
# Epoch: 120, Erro do Modelo: 1.432799220085144
# Epoch: 121, Erro do Modelo: 1.4179728031158447
# Epoch: 122, Erro do Modelo: 1.4033900499343872
# Epoch: 123, Erro do Modelo: 1.389150857925415
# Epoch: 124, Erro do Modelo: 1.3751643896102905
# Epoch: 125, Erro do Modelo: 1.361392617225647
# Epoch: 126, Erro do Modelo: 1.3478834629058838
# Epoch: 127, Erro do Modelo: 1.3346805572509766
# Epoch: 128, Erro do Modelo: 1.3216959238052368
# Epoch: 129, Erro do Modelo: 1.3088973760604858
# Epoch: 130, Erro do Modelo: 1.2964427471160889
# Epoch: 131, Erro do Modelo: 1.2841072082519531
# Epoch: 132, Erro do Modelo: 1.272046685218811
# Epoch: 133, Erro do Modelo: 1.2601134777069092
# Epoch: 134, Erro do Modelo: 1.2485156059265137
# Epoch: 135, Erro do Modelo: 1.2370445728302002
# Epoch: 136, Erro do Modelo: 1.225784182548523
# Epoch: 137, Erro do Modelo: 1.2147036790847778
# Epoch: 138, Erro do Modelo: 1.203816533088684
# Epoch: 139, Erro do Modelo: 1.193137288093567
# Epoch: 140, Erro do Modelo: 1.1826072931289673
# Epoch: 141, Erro do Modelo: 1.1722400188446045
# Epoch: 142, Erro do Modelo: 1.1620063781738281
# Epoch: 143, Erro do Modelo: 1.1520274877548218
# Epoch: 144, Erro do Modelo: 1.1422065496444702
# Epoch: 145, Erro do Modelo: 1.1324888467788696
# Epoch: 146, Erro do Modelo: 1.1229453086853027
# Epoch: 147, Erro do Modelo: 1.1135458946228027
# Epoch: 148, Erro do Modelo: 1.1042931079864502
# Epoch: 149, Erro do Modelo: 1.095163106918335

# %% [markdown]
# Observe como o erro foi reduzido a cada passada, nitidamente o aprendizado ocorrendo. Vamos agora usar o modelo para fazer previsões.

# %%
# Função para obter uma previsão
def get_resultado_previsto(input, dic_inverso_palavra):
    index = np.argmax(input)
    return dic_inverso_palavra[index]

# %%
# Função para prever sentenças (aplicamos aos novos dados o mesmo tratamento usado nos dados de treino)
def preve_sentenca(sentence):
    
    # Dividimos a sentença com split
    sentence_split = sentence.replace('.','').lower().split()
    
    # Criamos o vetor de sentença
    sentence_vector = make_sentence_vector(sentence_split, dic_palavra)
    
    # Faz a previsão com o modelo
    prediction_array = modelo(sentence_vector).data.numpy()
    
    # Print dos resultados
    print('Palavras Anteriores: {}\n'.format(sentence_split[:2]))
    print('Palavra Prevista: {}\n'.format(get_resultado_previsto(prediction_array[0], dic_inverso_palavra)))
    print('Palavras Seguintes: {}\n'.format(sentence_split[2:]))

# %% [markdown]
# ### Previsões com o Modelo

# %% [markdown]
# Dentro da frase: **"ausência de intimação anterior para realizar"**, vejamos se o modelo consegue prever a palavra.
#
# Vou omitir a palavra **intimação** e essa deve ser a palavra prevista pelo modelo. Vamos passar como dados de entrada as duas palavras anteriores e as duas palavras posteriores.

# %%
# Previsão com o modelo
preve_sentenca('ausência de anterior para')
# Out:
# Palavras Anteriores: ['ausência', 'de']
#
# Palavra Prevista: intimação
#
# Palavras Seguintes: ['anterior', 'para']

# %%
preve_sentenca('ausência de anterior para')
# Out:
# Palavras Anteriores: ['ausência', 'de']
#
# Palavra Prevista: intimação
#
# Palavras Seguintes: ['anterior', 'para']

# %%
# Emdedding da palavra
print(modelo.get_word_emdedding('intimação'))
# Out:
# tensor([[ 1.4879, -0.6620, -1.2427, -0.5468, -1.4584,  0.3871, -0.0306,  0.4475,
#           0.4137,  0.5131,  0.1360,  0.8099,  0.3717, -0.8087,  0.2396,  0.5007,
#           0.2054,  0.4953,  0.0442,  1.3942]], grad_fn=<ViewBackward0>)

# %% [markdown]
# Perfeito! O modelo fez a previsão da sentença no Embargo de Declaração! Mais um exemplo.

# %% [markdown]
# Dentro da frase: **"devendo incidir juros de 1%"**, vejamos se o modelo consegue prever a palavra.
#
# Vou omitir a palavra **juros** e essa deve ser a palavra prevista pelo modelo. Vamos passar como dados de entrada as duas palavras anteriores e as duas palavras posteriores.

# %%
# Previsão com o modelo
preve_sentenca('devendo incidir de 1%')
# Out:
# Palavras Anteriores: ['devendo', 'incidir']
#
# Palavra Prevista: juros
#
# Palavras Seguintes: ['de', '1%']

# %% [markdown]
# Perfeito! O modelo fez a previsão da sentença no Embargo de Declaração! E o CBoW não é o modelo mais avançado em PLN.

# %% [markdown]
# # Fim
