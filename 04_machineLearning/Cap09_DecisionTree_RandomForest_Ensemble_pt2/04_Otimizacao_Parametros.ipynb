# %% [markdown]
# # <font color='blue'>Otimização dos Parâmetros com Randomized Search</font>

# %% [markdown]
# Todo modelo de Machine Learning possui parâmetros que permitem a customização do modelo. Esses parâmetros também são chamados de hiperparâmetros.
#
# Em programação os algoritmos de Machine Learning são representados por funções e cada função possui os parâmetros de customização, exatamente o que chamamos de hiperparâmetros.
#
# É comum ainda que as pessoas se refiram aos coeficientes do modelo (encontrados ao final do treinamento) como parâmetros.
#
# Parte do nosso trabalho como Cientistas de Dados é encontrar a melhor combinação de hiperparâmetros para cada modelo.
#
# Em Métodos Ensemble esse trabalho é ainda mais complexo, pois temos os hiperparâmetros do estimador base e os hiperparâmetros do modelo ensemble, conforme este exemplo abaixo:
#
# * Estimador base:
#
# estim_base = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski', metric_params=None, n_jobs=None, n_neighbors=5, p=2, weights='uniform')
#
# * Modelo Ensemble:
#
# BaggingClassifier(base_estimator=estim_base,
#                   bootstrap=True, bootstrap_features=False, max_features=0.5,
#                   max_samples=0.5, n_estimators=10, n_jobs=None,
#                   oob_score=False, random_state=None, verbose=0,
#                   warm_start=False)

# %% [markdown]
# # <font color='red'>-----------------------------</font>
#
# # <font color='GREEN'>Extremely Randomized Forest</font>

# %% [markdown]
# Modelo padrão, com hiperparâmetros escolhidos manualmente

# %%
# Imports
import pandas as pd
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# carrega o dataset
data = pd.read_excel("C:/formacao_dataScience_DSA_DADOS/04_machineLearning/Cap09/dados_python/credit.xls", skiprows=1)

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
data["default payment next month"]
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default payment next month, Length: 30000, dtype: int64

# %%
# Variável Target 
target = "default payment next month"
y = np.asarray(data[target])

# %%
# Variáveis preditoras
features = data.columns.drop({'ID', target})
X = np.asarray(data[features])

# %%
len(X)
# Out:
# 30000

# %%
X_test, y_test = X[21000:], y[21000:]
X_train, y_train = X[:21000], y[:21000]

# %%
# # Divisão de dados em treino e teste
# X_train, y_train, X_teste, y_teste = train_test_split(X, 
#                                                       y, 
#                                                       test_size=0.30)

# %%
# Classificador
clf = ExtraTreesClassifier(n_estimators=500, random_state= 99)

# %%
# Treinando o modelo
clf.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(n_estimators=500, random_state=99)

# %%
clf.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 500,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 99,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Score
scores = cross_val_score(clf, 
                         X_train, 
                         y_train, 
                         cv = 3,
                         scoring= "accuracy",
                         n_jobs= -1)

# %%
# imprimindo os resultados 
print(f"ExtraTreesClassifier -> ACC em treino: Média = {round(np.mean(scores), 3)}")
print(f"ExtraTreesClassifier -> Desvio padrão = {round(np.std(scores),3)}")
# Out:
# ExtraTreesClassifier -> ACC em treino: Média = 0.805
# ExtraTreesClassifier -> Desvio padrão = 0.009

# %%
print(f"Pontuação do ada_clf_v1 => {scores}")
# Out:
# Pontuação do ada_clf_v1 => [0.79785714 0.79942857 0.81871429]

# %%
# Fazendo previsões 
y_pred = clf.predict(X_test)

# %%
# Confusion Matrix
confusion___matrix = confusion_matrix(y_test, y_pred)
print(confusion___matrix)
# Out:
# [[6774  386]
#  [1190  650]]

# %%
# Acurácia em teste 
print(f"Acurácia em teste => {round(accuracy_score(y_test, y_pred),2)}")
# Out:
# Acurácia em teste => 0.82

# %% [markdown]
# # <font color='red'>-----------------------------</font>
#
# ## <font color='GREEN'>Otimização dos Hiperparâmetros com Randomized Search</font>

# %% [markdown]
# O Randomized Search gera amostras dos parâmetros dos algoritmos a partir de uma distribuição randômica uniforme para um número fixo de interações. Um modelo é construído e testado para cada combinação de parâmetros.

# %%
# Imports

from sklearn.model_selection import RandomizedSearchCV

# %%
# Definição dos parâmetros
param_dist = {"max_depth": [1, 3, 7, 8, 12, None],
              "max_features": [8, 9, 10, 11, 16, 22],
              "min_samples_split": [8, 10, 11, 14, 16, 19],
              "min_samples_leaf": [1, 2, 3, 4, 5, 6, 7],
              "bootstrap": [True, False]}

# Para o classificador criado com ExtraTrees, testamos diferentes combinações de parâmetros 
rsearch = RandomizedSearchCV(clf, 
                             param_distributions= param_dist,
                             n_iter= 25,
                             return_train_score= True)

# %%
# Aplicando o resultado ao conjunto de dados de treino e obtendo o score
rsearch.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=ExtraTreesClassifier(n_estimators=500,
#                                                   random_state=99),
#                    n_iter=25,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [1, 3, 7, 8, 12, None],
#                                         'max_features': [8, 9, 10, 11, 16, 22],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5, 6,
#                                                              7],
#                                         'min_samples_split': [8, 10, 11, 14, 16,
#                                                               19]},
#                    return_train_score=True)

# %%
# RESULTADO 
rsearch.cv_results_

# Imprimindo o melhor estimador 
bestclf = rsearch.best_estimator_
print(bestclf)
# Out:
# ExtraTreesClassifier(max_depth=12, max_features=11, min_samples_leaf=2,
#                      min_samples_split=10, n_estimators=500, random_state=99)

# %%
# Aplicando o melhor estimador para realizar as previsões 
y_predict = bestclf.predict(X_test)

# %%
y_test = np.array(y_test)
y_predict = np.array(y_predict)

# Confusion Matrix
confusionMatrix = confusion_matrix(y_test, y_predict)
print(f"Matriz de confusão => {confusionMatrix}")

# Acurácia 
accuracy = accuracy_score(y_test, y_predict)
print(f"Acurácia => {accuracy}")
# Out:
# Matriz de confusão => [[6895  265]
#  [1202  638]]
# Acurácia => 0.837

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
type(y_predict)
# Out:
# numpy.ndarray

# %% [markdown]
# # <font color='red'>-----------------------------</font>
#
# # <font color='GREEN'>Grid Search x Randomized Search para Estimação dos Hiperparâmetros</font>

# %% [markdown]
# O Grid Search realiza metodicamente combinações entre todos os parâmetros do algoritmo, criando um grid.

# %%
# Imports

import numpy as np
from time import time
from scipy.stats import randint as sp_randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import load_digits

# Obtém o dataset
digits = load_digits()
X_comparativo, y_comparativo = digits.data, digits.target

# Construindo o classificador
clf_testes = RandomForestClassifier(n_estimators = 20)

# %%
# Randomized Search

# Valores dos parametros que serão testados 
param_distribuicao = {
 "max_depth": [3, None],
 "max_features": sp_randint(1,11),
 "min_samples_split": sp_randint(1,11),
 "bootstrap": [True, False],
 "criterion": ["gini", "entropy"]}

# Executando o Randomized Search
n_iter_search = 20
random_search = RandomizedSearchCV(clf_testes,
                                   param_distributions= param_distribuicao,
                                   n_iter = n_iter_search,
                                   return_train_score = True)

start = time()
random_search.fit(X_comparativo, y_comparativo)
print(f"RandomizedSearchCV executou em {round(time()- start, 2)} segundos, para {n_iter_search} candidatos")

# Imprime as combinações dos parametros e suas respectivas médias e acc
random_search.cv_results_
# Out:
# RandomizedSearchCV executou em 8.39 segundos, para 20 candidatos
# {'mean_fit_time': array([0.10352502, 0.13533678, 0.05096722, 0.04557314, 0.1065958 ,
#         0.06952639, 0.05931425, 0.05921731, 0.05126777, 0.0633235 ,
#         0.06275144, 0.04122658, 0.04412975, 0.09494052, 0.0602571 ,
#         0.06468406, 0.04523349, 0.09447331, 0.03956356, 0.11320076]),
#  'std_fit_time': array([0.0247363 , 0.01142319, 0.00423586, 0.00095839, 0.00469769,
#         0.00268937, 0.00616711, 0.00263822, 0.00469568, 0.00529783,
#         0.00524585, 0.00609405, 0.00671404, 0.00461427, 0.00626679,
#         0.00658622, 0.00301913, 0.01029195, 0.00305257, 0.00359618]),
#  'mean_score_time': array([0.00539565, 0.0047689 , 0.00320091, 0.00408812, 0.00561738,
#         0.00412278, 0.00401626, 0.00523248, 0.00366402, 0.00465236,
#         0.00499973, 0.00349112, 0.00444632, 0.00491452, 0.00404449,
#         0.00450258, 0.00362673, 0.00459795, 0.0045579 , 0.00465617]),
#  'std_score_time': array([0.00138876, 0.00090862, 0.00064564, 0.0006542 , 0.00070222,
#         0.0010157 , 0.000673  , 0.00075859, 0.00034041, 0.00042913,
#         0.00074365, 0.00044939, 0.00087473, 0.00042106, 0.00078964,
#         0.00028963, 0.00044976, 0.00108018, 0.00084979, 0.00029602]),
#  'param_bootstrap': masked_array(data=[False, False, True, True, False, False, True, True,
#                     True, False, True, False, True, True, True, True, True,
#                     True, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'entropy', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'gini', 'entropy', 'gini', 'entropy',
#                     'gini', 'entropy', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[None, None, 3, 3, None, 3, 3, None, 3, None, None, 3,
#                     3, None, 3, 3, 3, None, 3, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[9, 10, 8, 5, 5, 9, 9, 2, 8, 3, 2, 2, 1, 5, 10, 10, 3,
#                     6, 3, 7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[3, 3, 10, 10, 10, 2, 7, 6, 3, 7, 8, 10, 8, 1, 6, 1, 6,
#                     8, 1, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 9,
#    'min_samples_split': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_split': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 8,
#    'min_samples_split': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 5,
#    'min_samples_split': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 5,
#    'min_samples_split': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 9,
#    'min_samples_split': 2},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 9,
#    'min_samples_split': 7},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 2,
#    'min_samples_split': 6},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 8,
#    'min_samples_split': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_split': 7},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 2,
#    'min_samples_split': 8},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 2,
#    'min_samples_split': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_split': 8},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 5,
#    'min_samples_split': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_split': 6},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_split': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_split': 6},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 6,
#    'min_samples_split': 8},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_split': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 7,
#    'min_samples_split': 4}],
#  'split0_test_score': array([0.92222222, 0.92777778, 0.81666667, 0.8       , 0.90555556,
#         0.87222222, 0.85555556, 0.89444444, 0.86666667, 0.91944444,
#         0.91111111, 0.80277778, 0.725     , 0.89722222, 0.79166667,
#         0.875     , 0.75555556, 0.91944444, 0.81111111, 0.94722222]),
#  'split1_test_score': array([0.88888889, 0.87222222, 0.74722222, 0.76388889, 0.9       ,
#         0.78888889, 0.74722222, 0.86388889, 0.80555556, 0.88333333,
#         0.88611111, 0.76666667, 0.66388889, 0.89722222, 0.76666667,
#         0.74722222, 0.775     , 0.88611111, 0.775     , 0.90833333]),
#  'split2_test_score': array([0.93593315, 0.94150418, 0.80222841, 0.7994429 , 0.92200557,
#         0.78272981, 0.84679666, 0.92479109, 0.83008357, 0.94428969,
#         0.89972145, 0.74930362, 0.7994429 , 0.93871866, 0.79387187,
#         0.81337047, 0.80779944, 0.93871866, 0.80779944, 0.94428969]),
#  'split3_test_score': array([0.96657382, 0.95264624, 0.87743733, 0.8551532 , 0.96100279,
#         0.83008357, 0.88022284, 0.94986072, 0.81337047, 0.96100279,
#         0.95264624, 0.7994429 , 0.82451253, 0.94986072, 0.82172702,
#         0.77437326, 0.85236769, 0.96935933, 0.84401114, 0.95543175]),
#  'split4_test_score': array([0.90529248, 0.93036212, 0.78272981, 0.77715877, 0.90529248,
#         0.79665738, 0.75487465, 0.87465181, 0.77715877, 0.90807799,
#         0.88857939, 0.76601671, 0.7270195 , 0.91086351, 0.78551532,
#         0.79387187, 0.78272981, 0.88300836, 0.77994429, 0.92200557]),
#  'mean_test_score': array([0.92378211, 0.92490251, 0.80525689, 0.79912875, 0.91877128,
#         0.81411637, 0.81693439, 0.90152739, 0.81856701, 0.92322965,
#         0.90763386, 0.77684154, 0.74797276, 0.91877747, 0.79188951,
#         0.80076756, 0.7946905 , 0.91932838, 0.8035732 , 0.93545652]),
#  'std_test_score': array([0.02661058, 0.02777991, 0.04295314, 0.03119014, 0.02237255,
#         0.03333947, 0.05495448, 0.03183216, 0.02952   , 0.02722481,
#         0.02419551, 0.02079688, 0.05752286, 0.0217058 , 0.01772613,
#         0.04308271, 0.03334912, 0.03256263, 0.02483812, 0.01750464]),
#  'rank_test_score': array([ 3,  2, 13, 16,  7, 12, 11,  9, 10,  4,  8, 19, 20,  6, 18, 15, 17,
#          5, 14,  1]),
#  'split0_train_score': array([1.        , 1.        , 0.84899095, 0.82741823, 1.        ,
#         0.87613083, 0.88726514, 0.99930411, 0.89283229, 1.        ,
#         0.99652053, 0.86917189, 0.84411969, 1.        , 0.82115518,
#         0.88726514, 0.80932498, 1.        , 0.86430063, 1.        ]),
#  'split1_train_score': array([1.        , 1.        , 0.83646486, 0.87334725, 1.        ,
#         0.87821851, 0.87613083, 1.        , 0.87404315, 1.        ,
#         0.99582463, 0.86082116, 0.81837161, 1.        , 0.85873347,
#         0.88587335, 0.88169798, 0.99791232, 0.86221294, 1.        ]),
#  'split2_train_score': array([1.        , 1.        , 0.85187761, 0.87899861, 1.        ,
#         0.86787204, 0.88178025, 1.        , 0.86648122, 1.        ,
#         0.99721836, 0.84840056, 0.84700974, 1.        , 0.86856745,
#         0.86369958, 0.86717663, 0.99930459, 0.87065369, 1.        ]),
#  'split3_train_score': array([1.        , 1.        , 0.8650904 , 0.84353268, 1.        ,
#         0.84075104, 0.86717663, 0.99930459, 0.82545202, 1.        ,
#         0.99582754, 0.81571627, 0.82892907, 1.        , 0.83936022,
#         0.80737135, 0.86648122, 0.99860918, 0.87413074, 1.        ]),
#  'split4_train_score': array([1.        , 1.        , 0.8852573 , 0.88595271, 1.        ,
#         0.89638387, 0.87204451, 0.99930459, 0.85396384, 1.        ,
#         0.99930459, 0.83657858, 0.84979138, 1.        , 0.87413074,
#         0.88873435, 0.88734353, 0.99721836, 0.87204451, 1.        ]),
#  'mean_train_score': array([1.        , 1.        , 0.85753622, 0.8618499 , 1.        ,
#         0.87187126, 0.87687947, 0.99958266, 0.8625545 , 1.        ,
#         0.99693913, 0.84613769, 0.8376443 , 1.        , 0.85238941,
#         0.86658875, 0.86240487, 0.99860889, 0.8686685 , 1.        ]),
#  'std_train_score': array([0.        , 0.        , 0.01658052, 0.02248676, 0.        ,
#         0.01813153, 0.00707053, 0.00034076, 0.02242564, 0.        ,
#         0.00129045, 0.01880499, 0.01203815, 0.        , 0.01959591,
#         0.03099963, 0.02775256, 0.00098366, 0.00460276, 0.        ])}

# %%
# Grid Search

# Valores dos parametros que serão testados 
param_gridSV = {
 "max_depth": [3, None],
 "max_features": [1, 3, 10],
 "min_samples_leaf": [1, 3, 10],
 "bootstrap": [True, False],
 "criterion": ["gini", "entropy"]}

# Executando o Randomized Search
n_iter_search = 20
grid_search = GridSearchCV(clf_testes,
                             param_grid= param_gridSV,
                             return_train_score = True)


start = time()
grid_search.fit(X_comparativo, y_comparativo)
print(f"GridSearchCV executou em {round(time()- start, 2)} segundos, para {n_iter_search} candidatos")

# Imprime as combinações dos parametros e suas respectivas médias e acc
grid_search.cv_results_
# Out:
# GridSearchCV executou em 23.34 segundos, para 20 candidatos
# {'mean_fit_time': array([0.03888497, 0.03219914, 0.03647342, 0.03865223, 0.04127269,
#         0.03761415, 0.04324121, 0.04682164, 0.04815116, 0.05665956,
#         0.04522481, 0.04265113, 0.06274109, 0.05466948, 0.05497117,
#         0.09178624, 0.08259697, 0.07241654, 0.03619161, 0.03755383,
#         0.03548713, 0.0403605 , 0.04199467, 0.04001975, 0.05244908,
#         0.05411744, 0.05194097, 0.06228547, 0.04855046, 0.04027133,
#         0.0808188 , 0.06867189, 0.05341554, 0.10350113, 0.09917488,
#         0.08156366, 0.02983069, 0.02736788, 0.02833128, 0.03251009,
#         0.03397036, 0.03325915, 0.04650059, 0.04435811, 0.0439877 ,
#         0.0526278 , 0.03800869, 0.03362055, 0.06624427, 0.05550332,
#         0.04931235, 0.10426826, 0.09235997, 0.08398738, 0.02930503,
#         0.02918677, 0.02947669, 0.03563967, 0.03657265, 0.03470712,
#         0.05246844, 0.0520277 , 0.05387096, 0.06235509, 0.0453599 ,
#         0.03703809, 0.07363968, 0.06556778, 0.05302958, 0.12256041,
#         0.11288772, 0.09077296]),
#  'std_fit_time': array([0.00405918, 0.00166869, 0.00157523, 0.00135314, 0.00341463,
#         0.00165458, 0.00195447, 0.00216662, 0.00120479, 0.00253036,
#         0.0029442 , 0.00652929, 0.00245256, 0.001046  , 0.00798957,
#         0.00298051, 0.00323492, 0.00354112, 0.00074365, 0.00192505,
#         0.00187034, 0.00139907, 0.00314708, 0.00195694, 0.00155334,
#         0.00059608, 0.00127924, 0.00226424, 0.00311391, 0.00235592,
#         0.00504841, 0.00633774, 0.0039164 , 0.00213695, 0.00418625,
#         0.00288717, 0.00107986, 0.00022772, 0.00231091, 0.00184198,
#         0.00187946, 0.00328176, 0.001534  , 0.0018829 , 0.00043438,
#         0.00557348, 0.0018373 , 0.0015462 , 0.00321056, 0.00056882,
#         0.00226399, 0.00308157, 0.00198979, 0.00547733, 0.00052006,
#         0.00021996, 0.0007297 , 0.00130807, 0.00236865, 0.00114921,
#         0.00087965, 0.00129355, 0.00099889, 0.00084068, 0.00059528,
#         0.00287264, 0.00088246, 0.00244666, 0.0023432 , 0.00380392,
#         0.00128547, 0.00168105]),
#  'mean_score_time': array([0.0031785 , 0.00312104, 0.00321732, 0.00311074, 0.00349193,
#         0.00301423, 0.00318999, 0.00356741, 0.00326004, 0.00421104,
#         0.0040019 , 0.0041595 , 0.0040925 , 0.00363235, 0.00443411,
#         0.00427494, 0.00410867, 0.003689  , 0.00392132, 0.00340896,
#         0.00350766, 0.00331702, 0.00322223, 0.00321212, 0.0032156 ,
#         0.00334778, 0.00326018, 0.0042891 , 0.00387034, 0.00396733,
#         0.00479879, 0.00531554, 0.00354996, 0.00395951, 0.00421777,
#         0.00475903, 0.00319333, 0.00341105, 0.00350637, 0.0037241 ,
#         0.00371766, 0.0035141 , 0.00320086, 0.0034534 , 0.00358701,
#         0.00517373, 0.0039619 , 0.00343137, 0.00423822, 0.00472975,
#         0.00426826, 0.00430355, 0.00401173, 0.00391231, 0.0034966 ,
#         0.00364652, 0.00352054, 0.00320368, 0.00334277, 0.00356836,
#         0.00378122, 0.00384812, 0.00409851, 0.00442643, 0.00400701,
#         0.00347509, 0.00447121, 0.00393848, 0.00381031, 0.00389719,
#         0.00437965, 0.00391459]),
#  'std_score_time': array([6.57642126e-04, 2.15674327e-04, 5.19482442e-04, 1.83718160e-04,
#         4.68051108e-04, 5.34454896e-04, 3.88548247e-04, 5.21272449e-04,
#         2.31831567e-04, 3.74399091e-04, 6.82444893e-04, 4.23321715e-04,
#         2.72981065e-04, 5.46797330e-04, 6.71396455e-04, 4.41881745e-04,
#         7.45025489e-04, 7.45458219e-04, 2.08739375e-04, 5.37267736e-04,
#         5.11706869e-04, 4.06648439e-04, 3.80928759e-04, 4.04519614e-04,
#         3.94254528e-04, 4.42353677e-04, 2.02069242e-04, 4.52154670e-04,
#         2.71132669e-04, 7.29505521e-04, 7.50523201e-04, 5.82579220e-04,
#         6.59951526e-04, 5.22459261e-04, 3.37967888e-04, 1.14736078e-03,
#         4.04152233e-04, 4.09056112e-04, 6.32918561e-04, 6.37767801e-04,
#         4.74335186e-04, 4.18565430e-04, 3.87690885e-04, 5.49494417e-04,
#         3.17110513e-04, 6.59679753e-04, 7.44853526e-05, 5.55136543e-04,
#         3.26235299e-04, 6.18362530e-04, 5.43481677e-04, 3.93585752e-04,
#         2.68515662e-04, 3.92383865e-04, 5.27160859e-04, 5.12301682e-04,
#         5.80332712e-04, 4.09461859e-04, 6.22529485e-04, 8.96896451e-04,
#         4.88893597e-04, 4.17211761e-04, 8.04379719e-04, 4.57195396e-04,
#         7.03708882e-04, 5.68752797e-04, 4.06998646e-04, 7.19128930e-05,
#         3.84846128e-04, 4.19417301e-04, 4.83659707e-04, 4.96118598e-04]),
#  'param_bootstrap': masked_array(data=[True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[3, 3, 3, 3, 3, 3, 3, 3, 3, None, None, None, None,
#                     None, None, None, None, None, 3, 3, 3, 3, 3, 3, 3, 3,
#                     3, None, None, None, None, None, None, None, None,
#                     None, 3, 3, 3, 3, 3, 3, 3, 3, 3, None, None, None,
#                     None, None, None, None, None, None, 3, 3, 3, 3, 3, 3,
#                     3, 3, 3, None, None, None, None, None, None, None,
#                     None, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3, 10, 10,
#                     10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3, 10,
#                     10, 10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3,
#                     10, 10, 10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3,
#                     3, 3, 10, 10, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3,
#                     10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10,
#                     1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3,
#                     10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10,
#                     1, 3, 10, 1, 3, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10}],
#  'split0_test_score': array([0.75555556, 0.71388889, 0.75833333, 0.83611111, 0.82777778,
#         0.85277778, 0.80277778, 0.79444444, 0.81666667, 0.90555556,
#         0.87777778, 0.83611111, 0.90833333, 0.91666667, 0.87222222,
#         0.91111111, 0.925     , 0.91111111, 0.76944444, 0.73333333,
#         0.8       , 0.81388889, 0.81388889, 0.84444444, 0.81666667,
#         0.79166667, 0.84444444, 0.88888889, 0.90555556, 0.88888889,
#         0.92777778, 0.9       , 0.90833333, 0.925     , 0.92777778,
#         0.88888889, 0.77777778, 0.775     , 0.79722222, 0.84444444,
#         0.84722222, 0.83333333, 0.77777778, 0.75555556, 0.77222222,
#         0.90555556, 0.88333333, 0.88333333, 0.92222222, 0.93611111,
#         0.89444444, 0.93333333, 0.93055556, 0.91111111, 0.74722222,
#         0.75277778, 0.79166667, 0.81944444, 0.80555556, 0.81944444,
#         0.85555556, 0.8       , 0.79166667, 0.88888889, 0.89444444,
#         0.89444444, 0.9       , 0.90277778, 0.89166667, 0.93333333,
#         0.925     , 0.89722222]),
#  'split1_test_score': array([0.74444444, 0.74444444, 0.74166667, 0.79166667, 0.78333333,
#         0.775     , 0.74166667, 0.72222222, 0.79444444, 0.86944444,
#         0.85277778, 0.82777778, 0.89166667, 0.85833333, 0.825     ,
#         0.91111111, 0.88888889, 0.84444444, 0.71111111, 0.75833333,
#         0.71944444, 0.79722222, 0.76666667, 0.8       , 0.775     ,
#         0.75833333, 0.76666667, 0.86944444, 0.84722222, 0.85555556,
#         0.88611111, 0.88055556, 0.86666667, 0.89444444, 0.91111111,
#         0.83055556, 0.71388889, 0.74166667, 0.68055556, 0.75277778,
#         0.77222222, 0.76388889, 0.70833333, 0.74444444, 0.775     ,
#         0.86944444, 0.87777778, 0.825     , 0.88333333, 0.91666667,
#         0.86111111, 0.89722222, 0.9       , 0.875     , 0.76388889,
#         0.73055556, 0.725     , 0.76944444, 0.71666667, 0.725     ,
#         0.75      , 0.75555556, 0.76111111, 0.87222222, 0.83055556,
#         0.85555556, 0.91388889, 0.90555556, 0.86944444, 0.88611111,
#         0.87777778, 0.83888889]),
#  'split2_test_score': array([0.8356546 , 0.7632312 , 0.85236769, 0.80779944, 0.7994429 ,
#         0.8189415 , 0.80222841, 0.77715877, 0.82172702, 0.91086351,
#         0.90807799, 0.88300836, 0.93036212, 0.94428969, 0.92200557,
#         0.95821727, 0.94707521, 0.9275766 , 0.77158774, 0.77158774,
#         0.71030641, 0.81615599, 0.84679666, 0.81615599, 0.80501393,
#         0.83008357, 0.80501393, 0.90807799, 0.87743733, 0.85793872,
#         0.93593315, 0.93036212, 0.88579387, 0.94428969, 0.94986072,
#         0.91364903, 0.77158774, 0.77715877, 0.74373259, 0.79387187,
#         0.8189415 , 0.81058496, 0.82172702, 0.75208914, 0.8189415 ,
#         0.93871866, 0.91086351, 0.88022284, 0.93871866, 0.94428969,
#         0.92479109, 0.94986072, 0.95543175, 0.92479109, 0.77994429,
#         0.78830084, 0.79665738, 0.77715877, 0.79665738, 0.76601671,
#         0.7632312 , 0.79665738, 0.77715877, 0.93871866, 0.89415042,
#         0.88022284, 0.94986072, 0.92479109, 0.91922006, 0.94707521,
#         0.94986072, 0.93314763]),
#  'split3_test_score': array([0.77158774, 0.86350975, 0.83844011, 0.8551532 , 0.79108635,
#         0.81337047, 0.84958217, 0.86072423, 0.85793872, 0.91922006,
#         0.90529248, 0.90807799, 0.94428969, 0.95264624, 0.93036212,
#         0.94428969, 0.94150418, 0.9275766 , 0.78551532, 0.76880223,
#         0.7994429 , 0.80222841, 0.86350975, 0.85793872, 0.8551532 ,
#         0.8189415 , 0.86629526, 0.94150418, 0.91086351, 0.89972145,
#         0.94986072, 0.95543175, 0.9275766 , 0.94986072, 0.94986072,
#         0.93593315, 0.78272981, 0.84958217, 0.80222841, 0.88857939,
#         0.80222841, 0.7994429 , 0.82451253, 0.81337047, 0.83008357,
#         0.93314763, 0.91364903, 0.91364903, 0.95821727, 0.94707521,
#         0.94150418, 0.96100279, 0.96100279, 0.93036212, 0.77158774,
#         0.84122563, 0.8356546 , 0.83286908, 0.8718663 , 0.8356546 ,
#         0.8551532 , 0.79387187, 0.88857939, 0.96100279, 0.9275766 ,
#         0.8913649 , 0.97214485, 0.94986072, 0.93871866, 0.95821727,
#         0.9637883 , 0.94707521]),
#  'split4_test_score': array([0.67966574, 0.65181058, 0.71587744, 0.76880223, 0.80779944,
#         0.77994429, 0.81058496, 0.78272981, 0.78551532, 0.88857939,
#         0.85793872, 0.84401114, 0.91086351, 0.90529248, 0.84401114,
#         0.93314763, 0.8913649 , 0.86350975, 0.72980501, 0.72980501,
#         0.73537604, 0.77715877, 0.79108635, 0.73816156, 0.78272981,
#         0.76601671, 0.75208914, 0.88579387, 0.84401114, 0.8356546 ,
#         0.89972145, 0.91086351, 0.87465181, 0.92479109, 0.89693593,
#         0.86908078, 0.77437326, 0.74651811, 0.71030641, 0.79665738,
#         0.78272981, 0.74094708, 0.77715877, 0.77715877, 0.7994429 ,
#         0.89693593, 0.88857939, 0.86908078, 0.93036212, 0.89693593,
#         0.8718663 , 0.9275766 , 0.90807799, 0.86629526, 0.73816156,
#         0.72144847, 0.64066852, 0.7632312 , 0.76044568, 0.74373259,
#         0.73537604, 0.81058496, 0.74930362, 0.90250696, 0.84679666,
#         0.86629526, 0.91643454, 0.90250696, 0.86350975, 0.91643454,
#         0.92479109, 0.8913649 ]),
#  'mean_test_score': array([0.75738162, 0.74737697, 0.78133705, 0.81190653, 0.80188796,
#         0.80800681, 0.801368  , 0.7874559 , 0.81525843, 0.89873259,
#         0.88037295, 0.85979728, 0.91710306, 0.91544568, 0.87872021,
#         0.93157536, 0.91876664, 0.8948437 , 0.75349273, 0.75237233,
#         0.75291396, 0.80133086, 0.81638966, 0.81134014, 0.80691272,
#         0.79300836, 0.80690189, 0.89874188, 0.87701795, 0.86755184,
#         0.91988084, 0.91544259, 0.89260446, 0.92767719, 0.92710925,
#         0.88762148, 0.76407149, 0.77798514, 0.74680904, 0.81526617,
#         0.80466883, 0.78963943, 0.78190189, 0.76852368, 0.79913804,
#         0.90876045, 0.89484061, 0.8742572 , 0.92657072, 0.92821572,
#         0.89874342, 0.93379913, 0.93101362, 0.90151192, 0.76016094,
#         0.76686165, 0.75792943, 0.79242959, 0.79023832, 0.77796967,
#         0.7918632 , 0.79133395, 0.79356391, 0.9126679 , 0.87870474,
#         0.8775766 , 0.9304658 , 0.91709842, 0.89651192, 0.92823429,
#         0.92824358, 0.90153977]),
#  'std_test_score': array([0.05007781, 0.06928371, 0.05421067, 0.03079168, 0.01531114,
#         0.02838919, 0.03457321, 0.04427389, 0.02523215, 0.01774447,
#         0.02306545, 0.03067659, 0.01831811, 0.03341334, 0.04164928,
#         0.01850129, 0.024498  , 0.03443665, 0.02815899, 0.01758678,
#         0.03905183, 0.01399618, 0.03539428, 0.04189085, 0.02838705,
#         0.02821278, 0.04373532, 0.02465299, 0.02806182, 0.0234261 ,
#         0.02351862, 0.02568374, 0.02241383, 0.01943192, 0.02098607,
#         0.03636849, 0.02536497, 0.03858739, 0.0476324 , 0.04676538,
#         0.02666293, 0.0330999 , 0.0420798 , 0.02491536, 0.02305212,
#         0.02525101, 0.01465094, 0.02871497, 0.0247056 , 0.01891135,
#         0.03054182, 0.02179367, 0.02442823, 0.02611319, 0.01540931,
#         0.04374582, 0.06857656, 0.02821069, 0.05145743, 0.04282183,
#         0.05258414, 0.01876473, 0.04962424, 0.0326173 , 0.03524553,
#         0.0147908 , 0.02650714, 0.01835088, 0.02878311, 0.02527274,
#         0.02932564, 0.03773549]),
#  'rank_test_score': array([67, 71, 59, 40, 46, 42, 47, 57, 39, 23, 29, 36, 13, 15, 30,  2, 12,
#         25, 68, 70, 69, 48, 37, 41, 43, 51, 44, 22, 33, 35, 11, 16, 27,  8,
#          9, 28, 64, 60, 72, 38, 45, 56, 58, 62, 49, 18, 26, 34, 10,  7, 21,
#          1,  3, 20, 65, 63, 66, 52, 55, 61, 53, 54, 50, 17, 31, 32,  4, 14,
#         24,  6,  5, 19]),
#  'split0_train_score': array([0.85455811, 0.78496868, 0.80375783, 0.8677801 , 0.87125957,
#         0.86290884, 0.87682672, 0.85316632, 0.85247042, 1.        ,
#         0.98469033, 0.93667363, 1.        , 0.99373695, 0.96938065,
#         0.99930411, 0.99443285, 0.97981907, 0.83368128, 0.81419624,
#         0.84272791, 0.85386221, 0.83855254, 0.8921364 , 0.86290884,
#         0.86151705, 0.88796103, 1.        , 0.98399443, 0.94780793,
#         1.        , 0.99721642, 0.96798887, 1.        , 0.99721642,
#         0.97146834, 0.84968685, 0.83368128, 0.82672234, 0.87195546,
#         0.87404315, 0.87056367, 0.84968685, 0.84133612, 0.8677801 ,
#         1.        , 0.99860821, 0.95963814, 1.        , 1.        ,
#         0.98190675, 1.        , 1.        , 0.98329854, 0.80514962,
#         0.82741823, 0.80654141, 0.87125957, 0.85455811, 0.8677801 ,
#         0.87682672, 0.86082116, 0.87543493, 1.        , 0.99652053,
#         0.96798887, 1.        , 1.        , 0.98329854, 1.        ,
#         1.        , 0.9874739 ]),
#  'split1_train_score': array([0.83646486, 0.81419624, 0.81002088, 0.88656924, 0.86082116,
#         0.85734168, 0.8559499 , 0.81419624, 0.87613083, 1.        ,
#         0.98886569, 0.94432846, 1.        , 0.99652053, 0.97216423,
#         1.        , 0.99860821, 0.96729297, 0.82950592, 0.82463466,
#         0.82741823, 0.88378566, 0.85247042, 0.8796103 , 0.88239388,
#         0.8559499 , 0.89004871, 1.        , 0.9874739 , 0.93041058,
#         1.        , 0.99721642, 0.96798887, 0.99930411, 0.99791232,
#         0.9763396 , 0.83576896, 0.86290884, 0.81628392, 0.87891441,
#         0.88587335, 0.8670842 , 0.86221294, 0.86847599, 0.87265136,
#         1.        , 0.99652053, 0.94780793, 1.        , 0.99930411,
#         0.98538622, 1.        , 1.        , 0.98608212, 0.84481559,
#         0.84620738, 0.82672234, 0.88656924, 0.86151705, 0.8434238 ,
#         0.87195546, 0.85386221, 0.86917189, 1.        , 0.99791232,
#         0.95824635, 1.        , 1.        , 0.98469033, 1.        ,
#         1.        , 0.98956159]),
#  'split2_train_score': array([0.89360223, 0.82267038, 0.84770515, 0.84561892, 0.87413074,
#         0.86369958, 0.85396384, 0.85535466, 0.86856745, 1.        ,
#         0.98748261, 0.94158554, 1.        , 0.9930459 , 0.97009736,
#         1.        , 0.99791377, 0.97426982, 0.85535466, 0.81710709,
#         0.79694019, 0.90125174, 0.8713491 , 0.86578581, 0.85257302,
#         0.84909597, 0.87899861, 1.        , 0.9798331 , 0.95201669,
#         1.        , 0.99791377, 0.96453408, 1.        , 0.99513213,
#         0.97844228, 0.8511822 , 0.83936022, 0.8240612 , 0.85257302,
#         0.86856745, 0.86439499, 0.84840056, 0.84283727, 0.84353268,
#         1.        , 0.99652295, 0.9659249 , 1.        , 1.        ,
#         0.98122392, 1.        , 1.        , 0.9867872 , 0.85257302,
#         0.83031989, 0.83936022, 0.84214186, 0.84214186, 0.84214186,
#         0.83310153, 0.86369958, 0.83518776, 1.        , 0.99791377,
#         0.95549374, 1.        , 1.        , 0.98470097, 1.        ,
#         1.        , 0.98956885]),
#  'split3_train_score': array([0.79694019, 0.83171071, 0.82127955, 0.86787204, 0.82684284,
#         0.85326843, 0.85187761, 0.87482615, 0.84353268, 1.        ,
#         0.9867872 , 0.92767733, 1.        , 0.9930459 , 0.95340751,
#         1.        , 0.99791377, 0.97426982, 0.81432545, 0.79833102,
#         0.82892907, 0.8581363 , 0.85883171, 0.86787204, 0.84214186,
#         0.82962448, 0.86022253, 1.        , 0.9867872 , 0.945758  ,
#         1.        , 0.99652295, 0.97218359, 1.        , 0.99652295,
#         0.97844228, 0.80180807, 0.84561892, 0.83240612, 0.84561892,
#         0.82545202, 0.83866481, 0.82267038, 0.8240612 , 0.84075104,
#         1.        , 0.99721836, 0.95757997, 1.        , 0.99930459,
#         0.98400556, 1.        , 1.        , 0.99095967, 0.77329624,
#         0.84840056, 0.86300417, 0.83936022, 0.86439499, 0.86091794,
#         0.86230876, 0.83657858, 0.86091794, 1.        , 0.99860918,
#         0.95827538, 1.        , 1.        , 0.98609179, 1.        ,
#         0.99930459, 0.99026426]),
#  'split4_train_score': array([0.80598053, 0.76773296, 0.84561892, 0.88456189, 0.88873435,
#         0.90820584, 0.88803894, 0.88317107, 0.87691238, 1.        ,
#         0.98817803, 0.95340751, 1.        , 0.99513213, 0.972879  ,
#         1.        , 0.99791377, 0.97357441, 0.82475661, 0.82614743,
#         0.82336579, 0.88317107, 0.87273992, 0.83657858, 0.8581363 ,
#         0.88942976, 0.87899861, 1.        , 0.9867872 , 0.93810848,
#         1.        , 0.99721836, 0.97218359, 1.        , 0.99860918,
#         0.98122392, 0.87691238, 0.8449235 , 0.80737135, 0.90125174,
#         0.86995828, 0.86995828, 0.87760779, 0.88734353, 0.89012517,
#         1.        , 0.99721836, 0.96383866, 1.        , 1.        ,
#         0.98748261, 1.        , 1.        , 0.99235049, 0.81919332,
#         0.80180807, 0.78929068, 0.88942976, 0.89082058, 0.87065369,
#         0.85535466, 0.90820584, 0.86856745, 1.        , 0.99721836,
#         0.97009736, 1.        , 1.        , 0.98956885, 1.        ,
#         1.        , 0.99235049]),
#  'mean_train_score': array([0.83750918, 0.80425579, 0.82567646, 0.87048044, 0.86435773,
#         0.86908487, 0.8653314 , 0.85614289, 0.86352275, 1.        ,
#         0.98720077, 0.94073449, 1.        , 0.99429628, 0.96758575,
#         0.99986082, 0.99735647, 0.97384522, 0.83152478, 0.81608329,
#         0.82387624, 0.8760414 , 0.85878874, 0.86839663, 0.85963078,
#         0.85712343, 0.8792459 , 1.        , 0.98497517, 0.94282034,
#         1.        , 0.99721758, 0.9689758 , 0.99986082, 0.9970786 ,
#         0.97718328, 0.84307169, 0.84529855, 0.82136899, 0.87006271,
#         0.86477885, 0.86213319, 0.8521157 , 0.85281082, 0.86296807,
#         1.        , 0.99721768, 0.95895792, 1.        , 0.99972174,
#         0.98400101, 1.        , 1.        , 0.9878956 , 0.81900556,
#         0.83083082, 0.82498376, 0.86575213, 0.86268652, 0.85698348,
#         0.85990943, 0.86463347, 0.861856  , 1.        , 0.99763483,
#         0.96202034, 1.        , 1.        , 0.9856701 , 1.        ,
#         0.99986092, 0.98984382]),
#  'std_train_score': array([0.0348657 , 0.02407319, 0.0180434 , 0.01476027, 0.02077133,
#         0.01992816, 0.01446384, 0.02386876, 0.01330753, 0.        ,
#         0.00143386, 0.00849972, 0.        , 0.00134801, 0.00720463,
#         0.00027836, 0.00148635, 0.00397625, 0.01355149, 0.00994148,
#         0.01496177, 0.01765716, 0.01266353, 0.01848677, 0.01331775,
#         0.01941655, 0.01053247, 0.        , 0.00283596, 0.0076718 ,
#         0.        , 0.00043982, 0.00290712, 0.00027836, 0.00119618,
#         0.00325175, 0.02453874, 0.00980398, 0.00871225, 0.01978928,
#         0.02058439, 0.011939  , 0.01810265, 0.02234094, 0.01857827,
#         0.        , 0.00076187, 0.00630942, 0.        , 0.0003408 ,
#         0.00228642, 0.        , 0.        , 0.00331315, 0.02854574,
#         0.01672938, 0.02557097, 0.02134616, 0.01602477, 0.01202547,
#         0.01533928, 0.02373628, 0.01410694, 0.        , 0.00070983,
#         0.00586047, 0.        , 0.        , 0.00214016, 0.        ,
#         0.00027816, 0.00156409])}
